# %%
# %pip install carla 
# %pip install opencv-python
# %pip install pygame
# Out:
# Collecting carla
#   Downloading carla-0.9.15-cp310-cp310-manylinux_2_27_x86_64.whl.metadata (876 bytes)
# Downloading carla-0.9.15-cp310-cp310-manylinux_2_27_x86_64.whl (31.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.9/31.9 MB 87.5 MB/s eta 0:00:00:00:010:01
# Installing collected packages: carla
# Successfully installed carla-0.9.15
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: opencv-python in /isis/home/hasana3/miniconda3/envs/carla/lib/python3.10/site-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in /isis/home/hasana3/miniconda3/envs/carla/lib/python3.10/site-packages (from opencv-python) (2.1.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pygame in /isis/home/hasana3/.local/lib/python3.10/site-packages (2.6.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import the CARLA Python API library 
import carla
import math
import random
import time
import queue
import numpy as np
import cv2
import pygame
from PIL import Image
import json
import os
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.10.15)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
# Connect to the client and get the world object
client = carla.Client('localhost', 2000) 
client.set_timeout(200.0)
world  = client.reload_world()
bp_lib = world.get_blueprint_library()
spawn_points = world.get_map().get_spawn_points()
